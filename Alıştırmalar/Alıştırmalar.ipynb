# %% [markdown]
# ### Sorun1:

# %% [markdown]
# Find a continet that has the highest number of companies.<br>
# Output the continent along with the corresponding number of companies.
#
# <br>(En fazla şirket sayısına sahip bir kıta bulun. İlgili şirket sayısıyla birlikte kıtayı çıkarın.)

# %%
import pandas as pd

# %%
veri=pd.read_csv("veri.csv")

veri
# Out:
#                        company                  sector  \
# 0                         ICBC              Financials
# 1      China Construction Bank              Financials
# 2   Agricultural Bank of China              Financials
# 3               JPMorgan Chase              Financials
# 4           Berkshire Hathaway              Financials
# ..                         ...                     ...
# 95                CVS Caremark        Consumer Staples
# 96                   ING Group              Financials
# 97      Saudi Basic Industries               Materials
# 98                  Merck & Co             Health Care
# 99                 Walt Disney  Consumer Discretionary
#
#                    industry      continent        country  marketvalue  sales  \
# 0               Major Banks           Asia          China        215.6  148.7
# 1            Regional Banks           Asia          China        174.4  121.3
# ...

# %%
veri["continent"].value_counts()
# Out:
# North America    40
# Europe           29
# Asia             23
# Australia         5
# South America     3
# Name: continent, dtype: int64

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Sorun2:

# %% [markdown]
# Her bisikletin en son ne zaman kullanıldığını bulun. Hem bisiklet numarasını hem de bisikletin son kullanımının tarih-zaman damgasını (yani, bisikletin iade edildiği tarih-saat) çıktısını alın. Sonuçları en son kullanılan bisikletlere göre sıralayın.

# %%
import pandas as pd

# %%
# Veri setini okuma
df=pd.read_csv("Bikes Last Used.csv")


# Veri setini CSV dosyasına kaydetme
df.to_csv('Bikes Last Used.csv', index=False)


df.head()
# Out:
#         duration  duration_seconds           start_time  \
# 0  0h 10m 47sec.               647  2012-03-25 10:30:00
# 1  0h 11m 45sec.               705  2012-03-28 18:59:00
# 2   0h 7m 45sec.               465  2012-03-12 22:30:00
# 3   0h 4m 27sec.               267  2012-03-12 20:11:00
# 4   0h 10m 2sec.               602  2012-02-03 09:06:00
#
#                               start_station  start_terminal  \
# 0                     17th & Corcoran St NW           31214
# 1  Rosslyn Metro / Wilson Blvd & Ft Myer Dr           31015
# 2                             3rd & H St NE           31616
# 3                            14th & G St NW           31238
# 4                   Lamont & Mt Pleasant NW           31107
#
#               end_time                 end_station  end_terminal bike_number  \
# 0  2012-03-25 10:40:00  Calvert St & Woodley Pl NW         31106      W00576
# 1  2012-03-28 19:11:00              21st & M St NW         31212      W00011
# ...

# %%
df[["end_time","bike_number"]].sort_values(by="end_time",ascending=False)
# Out:
#                end_time bike_number
# 10  2012-03-31 19:28:00      W01278
# 99  2012-03-31 15:37:00      W01097
# 55  2012-03-31 12:10:00      W00270
# 14  2012-03-31 10:44:00      W01006
# 16  2012-03-31 09:24:00      W01242
# ..                  ...         ...
# 73  2012-01-10 14:17:00      W00888
# 30  2012-01-08 11:54:00      W00191
# 37  2012-01-07 21:04:00      W00566
# 19  2012-01-05 08:34:00      W00380
# 36  2012-01-01 01:23:00      W01213
#
# [100 rows x 2 columns]

# %%
df["bitis"]=df.end_time.apply(lambda x: x[11:])

df["bitis"]
# Out:
# 0     10:40:00
# 1     19:11:00
# 2     22:37:00
# 3     20:15:00
# 4     09:16:00
#         ...
# 95    21:01:00
# 96    12:18:00
# 97    19:34:00
# 98    11:02:00
# 99    15:37:00
# Name: bitis, Length: 100, dtype: object

# %%
df["bitis"]=df["bitis"].str.replace(":00","").str.replace(":",".").astype(float)

df["bitis"]
# Out:
# 0     10.40
# 1     19.11
# 2     22.37
# 3     20.15
# 4      9.16
#       ...
# 95    21.01
# 96    12.18
# 97    19.34
# 98    11.02
# 99    15.37
# Name: bitis, Length: 100, dtype: float64

# %%
df["baslangic"]=df.start_time.apply(lambda x: x[11:])

df["baslangic"]
# Out:
# 0     10:30:00
# 1     18:59:00
# 2     22:30:00
# 3     20:11:00
# 4     09:06:00
#         ...
# 95    20:40:00
# 96    12:03:00
# 97    18:57:00
# 98    10:22:00
# 99    15:13:00
# Name: baslangic, Length: 100, dtype: object

# %%
df["baslangic"]=df["baslangic"].str.replace(":00","").str.replace(":",".").astype(float)

df["baslangic"]
# Out:
# 0     10.30
# 1     18.59
# 2     22.30
# 3     20.11
# 4      9.06
#       ...
# 95    20.40
# 96    12.03
# 97    18.57
# 98    10.22
# 99    15.13
# Name: baslangic, Length: 100, dtype: float64

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Sorun3:

# %% [markdown]
# En çok doktor randevusu alan cinsiyeti bulun. Karşılık gelen randevu sayısıyla birlikte cinsiyeti de yazdırın.

# %%
import pandas as pd

# %%
# Veri setini okuma
df=pd.read_csv("Gender With Most Doctor Appointments.csv")


# Veri setini CSV dosyasına kaydetme
df.to_csv('Gender With Most Doctor Appointments.csv', index=False)


df.head()
# Out:
#          patientid  appointmentid gender         scheduledday appointmentday  \
# 0  914121144686824        5709776      M  2016-05-17 14:29:43     2016-06-03
# 1      54921576586        5551813      F  2016-04-06 14:45:46     2016-05-09
# 2   52587225747632        5649314      F  2016-05-02 19:01:13     2016-05-12
# 3    6769994598599        5663542      M  2016-05-05 10:12:16     2016-05-05
# 4    4326542238648        5709813      F  2016-05-17 14:35:22     2016-06-06
#
#    age     neighbourhood  scholarship  hipertension  diabetes  alcoholism  \
# 0    3    JARDIM CAMBURI            0             0         0           0
# 1   31       MARIA ORTIZ            0             0         0           0
# 2   66     SANTOS DUMONT            0             0         0           0
# 3   21        TABUAZEIRO            0             0         0           0
# 4   34  ILHA DO PRÍNCIPE            1             0         0           0
#
#    handcap  sms_received no_show
# ...

# %%
df["gender"].value_counts()  #Bu kadar


# Randevu alan Kadın sayısı 58, Erkek sayısı 42
# Out:
# F    58
# M    42
# Name: gender, dtype: int64

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Sorun4:

# %% [markdown]
# Çalışan unvanlarına ve cinsiyete göre ortalama toplam ücreti bulun. Toplam tazminat, her çalışanın hem maaşı hem de ikramiyesi eklenerek hesaplanır. Ancak, her çalışan ikramiye almaz, bu nedenle ikramiyesiz çalışanları hesaplamanızda dikkate almayın. Çalışan birden fazla ikramiye alabilir. Çalışan unvanını, cinsiyetini (yani cinsiyetini) ortalama toplam ücretle birlikte çıktılayın.

# %%
import pandas as pd

# %%
# Veri setini okuma
df=pd.read_csv("Income By Title and Gender.csv")


# Veri setini CSV dosyasına kaydetme
df.to_csv('Income By Title and Gender.csv', index=False)


df
# Out:
#     id first_name last_name  age sex employee_title  department  salary  \
# 0    5        Max    George   26   M          Sales       Sales    1300
# 1   13      Katty      Bond   56   F        Manager  Management  150000
# 2   11    Richerd      Gear   57   M        Manager  Management  250000
# 3   10   Jennifer      Dion   34   F          Sales       Sales    1000
# 4   19     George       Joe   50   M        Manager  Management  100000
# 5   18      Laila      Mark   26   F          Sales       Sales    1000
# 6   20     Sarrah     Bicky   31   F   Senior Sales       Sales    2000
# 7   21      Suzan       Lee   34   F          Sales       Sales    1300
# 8   22      Mandy      John   31   F          Sales       Sales    1300
# 9   23    Britney     Berry   45   F          Sales       Sales    1200
# 10  25       Jack      Mick   29   M          Sales       Sales    1300
# 11  26        Ben       Ten   43   M          Sales       Sales    1300
# ...

# %%
df["salary"]=df["salary"]+df["target"]

df["salary"]
# Out:
# 0       1500
# 1     150000
# 2     250000
# 3       1200
# 4     100000
# 5       1200
# 6       2200
# 7       1500
# 8       1500
# 9       1400
# 10      1500
# 11      1450
# 12      1400
# 13      1480
# 14      1400
# 15      1500
# 16      1800
# 17      1200
# 18      2400
# 19      1300
# 20      1200
# 21      1200
# 22       850
# 23      1500
# 24      1400
# 25      1640
# 26    200000
# 27      1200
# 28      2200
# 29      1120
# Name: salary, dtype: int64

# %%
df.groupby(["employee_title","sex"])[["salary"]].mean()
# Out:
#                       salary
# employee_title sex
# Auditor        F      1025.0
#                M      1250.0
# Manager        F    175000.0
#                M    175000.0
# Sales          F      1412.5
#                M      1395.0
# Senior Sales   F      2200.0
#                M      2080.0

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Sorun5:

# %% [markdown]
# Find the 3 most profitable companies in the entire world.
# Output the result along with the corresponding company name.
# Sort the result based on profits in descending order.
#
# Tüm dünyadaki en kârlı 3 şirketi bulun. Sonucu ilgili şirket adıyla birlikte çıktılayın. Sonucu karlara göre azalan düzende sıralayın.

# %%
import pandas as pd

# %%
# Veri setini okuma
df=pd.read_csv("Most Profitable Companies.csv")


# Veri setini CSV dosyasına kaydetme
df.to_csv('Most Profitable Companies.csv', index=False)

df.head()
# Out:
#                       company      sector             industry      continent  \
# 0                        ICBC  Financials          Major Banks           Asia
# 1     China Construction Bank  Financials       Regional Banks           Asia
# 2  Agricultural Bank of China  Financials       Regional Banks           Asia
# 3              JPMorgan Chase  Financials          Major Banks  North America
# 4          Berkshire Hathaway  Financials  Investment Services  North America
#
#          country  marketvalue  sales  profits  assets  rank  \
# 0          China        215.6  148.7     42.7  3124.9     1
# 1          China        174.4  121.3     34.2  2449.5     2
# 2          China        141.1  136.4     27.0  2405.4     3
# 3  United States        229.7  105.7     17.3  2435.3     4
# 4  United States        309.1  178.8     19.5   493.4     5
#
#                                        forbeswebpage
# 0              http://www.forbes.com/companies/icbc/
# ...

# %%
df[["company","profits"]].sort_values(by="profits",ascending=False).head(3)
# Out:
#     company  profits
# 0      ICBC     42.7
# 20  Gazprom     39.0
# 14    Apple     37.0
